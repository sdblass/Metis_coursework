# %%
import requests, re
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time, random
from urllib.request import urlopen
import urllib.parse
import numpy as np
from IPython.display import display

# %%
def get_soup(url): # Retrieves soup from website using py requests module and 'person' headers
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:95.0) Gecko/20100101 Firefox/95.0',
        'Accept-Language': 'en-US,en;q=0.5',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
        'Accept-Encoding': 'gzip, deflate, br',
        'Referer': 'https://duckduckgo.com/'
        }
    response = requests.get(url, headers=headers)
    status = response.status_code
    if status == 200:
      page = response.text
      soup = bs(page)
    else:
      print(f"Oops! Received status code {status}")
    return soup

# %%
def scrape_goodreads(url): # returns a df containing titles, ratings, urls, date published
    soup = get_soup(url)
    list_results = []
    
    # get list of titles
    soup_titles = soup.find_all('a', class_='bookTitle')
    titles = [title.text.strip() for title in soup_titles]
    
    # get authors
    author_info = soup.find_all('a', class_='authorName')
    authors = [author.text for author in author_info]
    author_urls = [author.get('href') for author in author_info]
    
    # get list of ratings 
    stars = soup.find_all(class_='minirating')
    stars = [star.text.split('—') for star in stars]

    # some stars have messed up title starting with a string. Clean this up.
    for star in stars:
        s1 = star[0].strip()
        star[0] = star[0].strip()
        m = re.search(r"\d", s1)
        index = m.start()
        if index:
            star[0] = star[0][index:]

        
    # clean up extra white spaces   
    cleaned_stars = []
    for line in stars:
        transfer = []
        for item in line:
            transfer += [item.strip()]
        cleaned_stars += [transfer]

    
    
    # get year published
#     dates = soup.find_all(class_='minirating')
#     dates = [date.parent.text.split()[-1] for date in dates]
    
    # get url for GR page for specific title
    urls = [url.get('href') for url in soup_titles]
    
    #assemble list of dicts for each title
    for i in range(len(titles)):
        results = {}
        title = titles[i]
        results['title'] = title
        results['author'] = authors[i]
        results['author_url'] = author_urls[i]
        
        if cleaned_stars[i][0][0].isnumeric():       
            results['stars'] = cleaned_stars[i][0]
        else: results['stars'] = 'error'
        results['number of ratings'] = cleaned_stars[i][1]
#         results['year published'] = dates[i]
        results['url'] = urls[i]
        left = '(' in titles[i]
        right = ')' in titles[i]
        pound = '#' in titles[i]
        if left and right and pound:
            results['is_series'] = True
            
            # clean up title
            pound_ind = title.index('#')
            right_ind = title.index(')', pound_ind)
            title = title[::-1]
            left_ind = title.index('(', title.index('#'))
            left_ind = len(title) - left_ind - 1
            title = title[::-1]
            title = title[:left_ind] + title[right_ind + 1:]
            title = title.strip()
            results['title'] = title

        else: results['is_series'] = False


        list_results += [results]

    # convert list of dicts into df
    list_results = pd.DataFrame(list_results)
    
    # clean and return df
    return list_results

# %%
def get_good_reads(first_page_url):
    base_url = first_page_url[:-1]
    df = pd.DataFrame()
    pages = list(range(1,11))
    random.shuffle(pages)
    for page_number in pages:
        url = base_url + str(page_number)
        df = df.append(scrape_goodreads(url))
        df.reset_index(drop=True, inplace=True)
#         display(df)
        df.to_csv('Figures/master_GR_df.csv')
        time.sleep(10 + random.uniform(-1,1))

# %%
get_good_reads('https://www.goodreads.com/list/show/1.Best_Books_Ever?page=8')
# Out:
#                                     title              author  \
# 0                                   Night         Elie Wiesel
# 1                        The Westing Game        Ellen Raskin
# 2                                  Hunted           P.C. Cast
# 3             We Need to Talk About Kevin      Lionel Shriver
# 4                          The Bean Trees  Barbara Kingsolver
# ..                                    ...                 ...
# 95  The Sisterhood of the Traveling Pants       Ann Brashares
# 96                                Tempted           P.C. Cast
# 97                   Howl and Other Poems      Allen Ginsberg
# 98                      Jitterbug Perfume         Tom Robbins
# 99                    Grimm's Fairy Tales         Jacob Grimm
#
#               stars  number of ratings  \
# 0   4.34 avg rating  1,076,237 ratings
# 1   4.00 avg rating    195,985 ratings
# 2   3.91 avg rating    178,631 ratings
# 3   4.04 avg rating    188,422 ratings
# 4   3.98 avg rating    140,989 ratings
# ..              ...                ...
# 95  3.81 avg rating    664,248 ratings
# 96  3.94 avg rating    162,671 ratings
# 97  4.12 avg rating    101,515 ratings
# 98  4.19 avg rating     74,960 ratings
# 99  4.13 avg rating     25,721 ratings
#
#                                                   url  is_series
# 0                               /book/show/1617.Night       True
# 1                     /book/show/902.The_Westing_Game      False
# 2                           /book/show/4134071-hunted       True
# 3        /book/show/80660.We_Need_to_Talk_About_Kevin      False
# 4                     /book/show/30868.The_Bean_Trees       True
# ..                                                ...        ...
# 95  /book/show/452306.The_Sisterhood_of_the_Travel...       True
# 96                         /book/show/6262365-tempted       True
# 97               /book/show/6295.Howl_and_Other_Poems      False
# 98                  /book/show/8682.Jitterbug_Perfume      False
# 99            /book/show/19351490-grimm-s-fairy-tales      False
#
# [100 rows x 6 columns]
#                           title              author            stars  \
# 0                         Night         Elie Wiesel  4.34 avg rating
# 1              The Westing Game        Ellen Raskin  4.00 avg rating
# 2                        Hunted           P.C. Cast  3.91 avg rating
# 3   We Need to Talk About Kevin      Lionel Shriver  4.04 avg rating
# 4                The Bean Trees  Barbara Kingsolver  3.98 avg rating
# ..                          ...                 ...              ...
# 95           A Room with a View        E.M. Forster  3.91 avg rating
# 96                 The 5th Wave         Rick Yancey  4.02 avg rating
# 97                  Bleak House     Charles Dickens  4.00 avg rating
# 98       Snow Falling on Cedars      David Guterson  3.85 avg rating
# 99                       Chosen           P.C. Cast  3.91 avg rating
#
#     number of ratings                                           url  is_series
# 0   1,076,237 ratings                         /book/show/1617.Night       True
# 1     195,985 ratings               /book/show/902.The_Westing_Game      False
# 2     178,631 ratings                     /book/show/4134071-hunted       True
# 3     188,422 ratings  /book/show/80660.We_Need_to_Talk_About_Kevin      False
# 4     140,989 ratings               /book/show/30868.The_Bean_Trees       True
# ..                ...                                           ...        ...
# 95    162,567 ratings            /book/show/3087.A_Room_with_a_View      False
# 96    429,786 ratings              /book/show/16101128-the-5th-wave       True
# 97    105,472 ratings                  /book/show/31242.Bleak_House      False
# 98    177,376 ratings       /book/show/77142.Snow_Falling_on_Cedars      False
# 99    235,276 ratings                     /book/show/1326258.Chosen       True
#
# [200 rows x 6 columns]
#                                                 title  \
# 0                                               Night
# 1                                    The Westing Game
# 2                                              Hunted
# 3                         We Need to Talk About Kevin
# 4                                      The Bean Trees
# ..                                                ...
# 95                                        Thoughtless
# 96                                           Factotum
# 97  The 5 Love Languages: The Secret to Love that ...
# 98                                             Bitten
# 99  Dodging Satan: My Irish/Italian, Sometimes Awe...
#
#                         author            stars  number of ratings  \
# 0                  Elie Wiesel  4.34 avg rating  1,076,237 ratings
# 1                 Ellen Raskin  4.00 avg rating    195,985 ratings
# 2                    P.C. Cast  3.91 avg rating    178,631 ratings
# 3               Lionel Shriver  4.04 avg rating    188,422 ratings
# 4           Barbara Kingsolver  3.98 avg rating    140,989 ratings
# ..                         ...              ...                ...
# 95               S.C. Stephens  4.09 avg rating    137,872 ratings
# 96            Charles Bukowski  3.93 avg rating     68,700 ratings
# 97                Gary Chapman  4.25 avg rating    350,393 ratings
# 98            Kelley Armstrong  4.00 avg rating    101,756 ratings
# 99  Kathleen Zamboni McCormick  4.29 avg rating     10,225 ratings
#
#                                              url  is_series
# 0                          /book/show/1617.Night       True
# 1                /book/show/902.The_Westing_Game      False
# 2                      /book/show/4134071-hunted       True
# 3   /book/show/80660.We_Need_to_Talk_About_Kevin      False
# 4                /book/show/30868.The_Bean_Trees       True
# ..                                           ...        ...
# 95               /book/show/13517535-thoughtless       True
# 96                    /book/show/497199.Factotum      False
# 97      /book/show/23878688-the-5-love-languages      False
# 98                       /book/show/11918.Bitten       True
# 99             /book/show/28009303-dodging-satan      False
#
# [300 rows x 6 columns]
#                            title              author            stars  \
# 0                          Night         Elie Wiesel  4.34 avg rating
# 1               The Westing Game        Ellen Raskin  4.00 avg rating
# 2                         Hunted           P.C. Cast  3.91 avg rating
# 3    We Need to Talk About Kevin      Lionel Shriver  4.04 avg rating
# 4                 The Bean Trees  Barbara Kingsolver  3.98 avg rating
# ..                           ...                 ...              ...
# 95  Murder on the Orient Express     Agatha Christie  4.19 avg rating
# 96     The Clan of the Cave Bear        Jean M. Auel  4.07 avg rating
# 97               Throne of Glass       Sarah J. Maas  4.18 avg rating
# 98          The Canterbury Tales    Geoffrey Chaucer  3.52 avg rating
# 99   The World According to Garp         John Irving  4.09 avg rating
#
#     number of ratings                                             url  \
# 0   1,076,237 ratings                           /book/show/1617.Night
# 1     195,985 ratings                 /book/show/902.The_Westing_Game
# 2     178,631 ratings                       /book/show/4134071-hunted
# 3     188,422 ratings    /book/show/80660.We_Need_to_Talk_About_Kevin
# 4     140,989 ratings                 /book/show/30868.The_Bean_Trees
# ..                ...                                             ...
# 95    468,866 ratings  /book/show/853510.Murder_on_the_Orient_Express
# 96    245,498 ratings   /book/show/40611463-the-clan-of-the-cave-bear
# 97    785,417 ratings              /book/show/7896527-throne-of-glass
# 98    203,891 ratings            /book/show/2696.The_Canterbury_Tales
# 99    213,689 ratings     /book/show/7069.The_World_According_to_Garp
#
#     is_series
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
# ..        ...
# 95       True
# 96       True
# 97       True
# 98      False
# 99      False
#
# [400 rows x 6 columns]
#                           title              author            stars  \
# 0                         Night         Elie Wiesel  4.34 avg rating
# 1              The Westing Game        Ellen Raskin  4.00 avg rating
# 2                        Hunted           P.C. Cast  3.91 avg rating
# 3   We Need to Talk About Kevin      Lionel Shriver  4.04 avg rating
# 4                The Bean Trees  Barbara Kingsolver  3.98 avg rating
# ..                          ...                 ...              ...
# 95       Everything, Everything         Nicola Yoon  4.02 avg rating
# 96         The Crying of Lot 49      Thomas Pynchon  3.68 avg rating
# 97                     Magician    Raymond E. Feist  4.27 avg rating
# 98      The Forty Rules of Love         Elif Shafak  4.13 avg rating
# 99          Valley of the Dolls   Jacqueline Susann  3.78 avg rating
#
#     number of ratings                                           url  is_series
# 0   1,076,237 ratings                         /book/show/1617.Night       True
# 1     195,985 ratings               /book/show/902.The_Westing_Game      False
# 2     178,631 ratings                     /book/show/4134071-hunted       True
# 3     188,422 ratings  /book/show/80660.We_Need_to_Talk_About_Kevin      False
# 4     140,989 ratings               /book/show/30868.The_Bean_Trees       True
# ..                ...                                           ...        ...
# 95    488,177 ratings     /book/show/18692431-everything-everything      False
# 96     80,587 ratings          /book/show/2794.The_Crying_of_Lot_49      False
# 97     66,598 ratings                     /book/show/43916.Magician       True
# 98    149,457 ratings    /book/show/6642715-the-forty-rules-of-love      False
# 99     54,877 ratings         /book/show/581811.Valley_of_the_Dolls      False
#
# [500 rows x 6 columns]
#                           title               author            stars  \
# 0                         Night          Elie Wiesel  4.34 avg rating
# 1              The Westing Game         Ellen Raskin  4.00 avg rating
# 2                        Hunted            P.C. Cast  3.91 avg rating
# 3   We Need to Talk About Kevin       Lionel Shriver  4.04 avg rating
# 4                The Bean Trees   Barbara Kingsolver  3.98 avg rating
# ..                          ...                  ...              ...
# 95            World Without End          Ken Follett  4.26 avg rating
# 96          The Glass Menagerie   Tennessee Williams  3.71 avg rating
# 97         Speaker for the Dead     Orson Scott Card  4.07 avg rating
# 98        Sense and Sensibility          Jane Austen  4.08 avg rating
# 99       The Merchant of Venice  William Shakespeare  3.79 avg rating
#
#     number of ratings                                           url  is_series
# 0   1,076,237 ratings                         /book/show/1617.Night       True
# 1     195,985 ratings               /book/show/902.The_Westing_Game      False
# 2     178,631 ratings                     /book/show/4134071-hunted       True
# 3     188,422 ratings  /book/show/80660.We_Need_to_Talk_About_Kevin      False
# 4     140,989 ratings               /book/show/30868.The_Bean_Trees       True
# ..                ...                                           ...        ...
# 95    225,485 ratings             /book/show/5064.World_Without_End       True
# 96    121,402 ratings          /book/show/92517.The_Glass_Menagerie      False
# 97    237,137 ratings          /book/show/7967.Speaker_for_the_Dead       True
# 98  1,048,592 ratings        /book/show/14935.Sense_and_Sensibility      False
# 99    170,582 ratings       /book/show/24128.The_Merchant_of_Venice      False
#
# [600 rows x 6 columns]
#                           title               author            stars  \
# 0                         Night          Elie Wiesel  4.34 avg rating
# 1              The Westing Game         Ellen Raskin  4.00 avg rating
# 2                        Hunted            P.C. Cast  3.91 avg rating
# 3   We Need to Talk About Kevin       Lionel Shriver  4.04 avg rating
# 4                The Bean Trees   Barbara Kingsolver  3.98 avg rating
# ..                          ...                  ...              ...
# 95           I Am the Messenger         Markus Zusak  4.02 avg rating
# 96         The Blood of Olympus         Rick Riordan  4.40 avg rating
# 97                   Small Gods      Terry Pratchett  4.30 avg rating
# 98                 Mystic River        Dennis Lehane  4.13 avg rating
# 99              House of Leaves  Mark Z. Danielewski  4.05 avg rating
#
#     number of ratings                                           url  is_series
# 0   1,076,237 ratings                         /book/show/1617.Night       True
# 1     195,985 ratings               /book/show/902.The_Westing_Game      False
# 2     178,631 ratings                     /book/show/4134071-hunted       True
# 3     188,422 ratings  /book/show/80660.We_Need_to_Talk_About_Kevin      False
# 4     140,989 ratings               /book/show/30868.The_Bean_Trees       True
# ..                ...                                           ...        ...
# 95    154,738 ratings           /book/show/19057.I_Am_the_Messenger      False
# 96    250,957 ratings      /book/show/18705209-the-blood-of-olympus       True
# 97    107,794 ratings                   /book/show/34484.Small_Gods       True
# 98    146,332 ratings                 /book/show/21671.Mystic_River      False
# 99    151,582 ratings              /book/show/24800.House_of_Leaves      False
#
# [700 rows x 6 columns]
#                           title              author            stars  \
# 0                         Night         Elie Wiesel  4.34 avg rating
# 1              The Westing Game        Ellen Raskin  4.00 avg rating
# 2                        Hunted           P.C. Cast  3.91 avg rating
# 3   We Need to Talk About Kevin      Lionel Shriver  4.04 avg rating
# 4                The Bean Trees  Barbara Kingsolver  3.98 avg rating
# ..                          ...                 ...              ...
# 95              Robinson Crusoe        Daniel Defoe  3.68 avg rating
# 96  Harry Potter Series Box Set        J.K. Rowling  4.72 avg rating
# 97          Midnight's Children      Salman Rushdie  3.98 avg rating
# 98          The English Patient    Michael Ondaatje  3.87 avg rating
# 99                     The Firm    Robin Waterfield  4.04 avg rating
#
#     number of ratings                                            url  \
# 0   1,076,237 ratings                          /book/show/1617.Night
# 1     195,985 ratings                /book/show/902.The_Westing_Game
# 2     178,631 ratings                      /book/show/4134071-hunted
# 3     188,422 ratings   /book/show/80660.We_Need_to_Talk_About_Kevin
# 4     140,989 ratings                /book/show/30868.The_Bean_Trees
# ..                ...                                            ...
# 95    269,538 ratings                /book/show/2932.Robinson_Crusoe
# 96    269,448 ratings  /book/show/862041.Harry_Potter_Series_Box_Set
# 97    111,295 ratings           /book/show/14836.Midnight_s_Children
# 98    122,214 ratings           /book/show/11713.The_English_Patient
# 99    599,882 ratings                       /book/show/5358.The_Firm
#
#     is_series
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
# ..        ...
# 95       True
# 96       True
# 97      False
# 98      False
# 99      False
#
# [800 rows x 6 columns]
#                             title               author            stars  \
# 0                           Night          Elie Wiesel  4.34 avg rating
# 1                The Westing Game         Ellen Raskin  4.00 avg rating
# 2                          Hunted            P.C. Cast  3.91 avg rating
# 3     We Need to Talk About Kevin       Lionel Shriver  4.04 avg rating
# 4                  The Bean Trees   Barbara Kingsolver  3.98 avg rating
# ..                            ...                  ...              ...
# 95                  Invisible Man        Ralph Ellison  3.89 avg rating
# 96        The Things They Carried          Tim O'Brien  4.13 avg rating
# 97      James and the Giant Peach           Roald Dahl  4.01 avg rating
# 98             The Complete Works  William Shakespeare  4.46 avg rating
# 99  All Creatures Great and Small        James Herriot  4.29 avg rating
#
#     number of ratings                                             url  \
# 0   1,076,237 ratings                           /book/show/1617.Night
# 1     195,985 ratings                 /book/show/902.The_Westing_Game
# 2     178,631 ratings                       /book/show/4134071-hunted
# 3     188,422 ratings    /book/show/80660.We_Need_to_Talk_About_Kevin
# 4     140,989 ratings                 /book/show/30868.The_Bean_Trees
# ..                ...                                             ...
# 95    168,139 ratings                  /book/show/16981.Invisible_Man
# 96    277,116 ratings       /book/show/133518.The_Things_They_Carried
# 97    423,472 ratings       /book/show/6689.James_and_the_Giant_Peach
# 98     54,051 ratings            /book/show/569564.The_Complete_Works
# 99    133,752 ratings  /book/show/32085.All_Creatures_Great_and_Small
#
#     is_series
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
# ..        ...
# 95      False
# 96      False
# 97      False
# 98      False
# 99       True
#
# [900 rows x 6 columns]
#                              title              author            stars  \
# 0                            Night         Elie Wiesel  4.34 avg rating
# 1                 The Westing Game        Ellen Raskin  4.00 avg rating
# 2                           Hunted           P.C. Cast  3.91 avg rating
# 3      We Need to Talk About Kevin      Lionel Shriver  4.04 avg rating
# 4                   The Bean Trees  Barbara Kingsolver  3.98 avg rating
# ..                             ...                 ...              ...
# 95                    The Notebook     Nicholas Sparks  4.12 avg rating
# 96                 Winnie-the-Pooh          A.A. Milne  4.32 avg rating
# 97  The Complete Stories and Poems     Edgar Allan Poe  4.37 avg rating
# 98      Interview with the Vampire           Anne Rice  4.00 avg rating
# 99         A Prayer for Owen Meany         John Irving  4.23 avg rating
#
#     number of ratings                                              url  \
# 0   1,076,237 ratings                            /book/show/1617.Night
# 1     195,985 ratings                  /book/show/902.The_Westing_Game
# 2     178,631 ratings                        /book/show/4134071-hunted
# 3     188,422 ratings     /book/show/80660.We_Need_to_Talk_About_Kevin
# 4     140,989 ratings                  /book/show/30868.The_Bean_Trees
# ..                ...                                              ...
# 95  1,464,216 ratings                 /book/show/33648131-the-notebook
# 96    301,205 ratings                 /book/show/99107.Winnie_the_Pooh
# 97    233,410 ratings  /book/show/23919.The_Complete_Stories_and_Poems
# 98    526,137 ratings      /book/show/43763.Interview_with_the_Vampire
# 99    298,820 ratings          /book/show/4473.A_Prayer_for_Owen_Meany
#
#     is_series
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
# ..        ...
# 95       True
# 96       True
# 97      False
# 98       True
# 99      False
#
# [1000 rows x 6 columns]

# %%
def get_good_reads_2(first_page_url):
    base_url = first_page_url[:-1]
    df = pd.DataFrame()
    pages = list(range(10,21))
    random.shuffle(pages)
    for page_number in pages:
        url = base_url + str(page_number)
        df = df.append(scrape_goodreads(url))
        df.reset_index(drop=True, inplace=True)
#         display(df)
        df.to_csv('Figures/master_GR_df_2.csv')
        time.sleep(10 + random.uniform(-1,1))

# %%
get_good_reads_2('https://www.goodreads.com/list/show/1.Best_Books_Ever?page=8')

# %%
testDF = scrape_goodreads('https://www.goodreads.com/search?q=rationality+steven+pinker')

# %%
testDF
# Out:
#                                                title           author  \
# 0  SUMMARY OF RATIONALITY BY STEVEN PINKER: What ...  Wilson Gabriels
# 1  Workbook: Rationality by Steven Pinker (IKPA):...             IKPA
# 2  Summary Analysis of Rationality By Steven Pink...      Caleb Reads
# 3  Rationality: What It Is, Why It Seems Scarce, ...    Steven Pinker
# 4  Summary Of Rationality: What It Is, Why It See...      James Baden
# 5  Steven Pinker Collection 3 Books Set (Enlighte...    Steven Pinker
# 6  Rationality: What It Is, Why It Seems Scarce, ...    Pinker Steven
# 7  Summary of Rationality: What It Is, Why It's S...        BestPrint
# 8             Summary of Steven Pinker’s Rationality       Bolt Books
#
#                                           author_url            stars  \
# 0  https://www.goodreads.com/author/show/21854615...  0.00 avg rating
# 1  https://www.goodreads.com/author/show/22023315...  0.00 avg rating
# 2  https://www.goodreads.com/author/show/21506417...  0.00 avg rating
# 3  https://www.goodreads.com/author/show/3915.Ste...  3.89 avg rating
# 4  https://www.goodreads.com/author/show/21836599...  1.00 avg rating
# 5  https://www.goodreads.com/author/show/3915.Ste...  0.00 avg rating
# 6  https://www.goodreads.com/author/show/21936798...  4.00 avg rating
# 7  https://www.goodreads.com/author/show/21345922...  0.00 avg rating
# 8  https://www.goodreads.com/author/show/22087178...  0.00 avg rating
#
#   number of ratings                                                url  \
# 0         0 ratings  /book/show/59349571-summary-of-rationality-by-...
# 1         0 ratings  /book/show/59699961-workbook?from_search=true&...
# 2         0 ratings  /book/show/59819996-summary-analysis-of-ration...
# 3     1,396 ratings  /book/show/56224080-rationality?from_search=tr...
# 4         2 ratings  /book/show/59131661-summary-of-rationality?fro...
# 5         0 ratings  /book/show/59149426-steven-pinker-collection-3...
# 6         3 ratings  /book/show/59406681-rationality?from_search=tr...
# 7         0 ratings  /book/show/59848357-summary-of-rationality?fro...
# 8         0 ratings  /book/show/60071748-summary-of-steven-pinker-s...
#
#    is_series
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False

# %%
import scrapeFunc

# %%
dir(scrapeFunc)
# Out:
# ['Options',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'bs',
#  'display',
#  'get_pages_year_authorAttr',
#  'get_soup',
#  'get_soup_driver',
#  'get_soup_driver_proxy',
#  'get_soup_proxy',
#  'import_df',
#  'np',
#  'pd',
#  'random',
#  're',
#  'requests',
#  'scrape_goodreads',
#  'search_imdb',
#  'time',
#  'urllib',
#  'urlopen',
#  'webdriver']

# %%
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/b1/x16nkyxn74s8p16m4l_9dqh00000gn/T/ipykernel_5298/2924239048.py in <module>
# ----> 1 driver.quit()
#
# NameError: name 'driver' is not defined
